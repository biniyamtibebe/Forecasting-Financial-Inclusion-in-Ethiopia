# %%
pre = series[series.index < event_year].mean()
post = series[series.index >= event_year].mean()

impact = post - pre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pre = series[series.index < event_year].mean()
#       2 post = series[series.index >= event_year].mean()
#       4 impact = post - pre
#
# NameError: name 'series' is not defined
